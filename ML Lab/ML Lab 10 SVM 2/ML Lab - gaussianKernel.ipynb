# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/BDSET /Lab/Lab_10/gaussian.csv')
dataset.head()
# Out:
#    Unnamed: 0    x     y  classlabels  probabilities
# 0           0  2.0   2.0            0       0.956055
# 1           1  5.0   7.0            0       0.657183
# 2           2  8.0   6.0            0       0.577017
# 3           3  4.0   8.0            0       0.636944
# 4           4  6.0  10.0            0       0.462753

# %% [markdown]
# #How to plot 3D scatter plot

# %%
# plt.scatter(df['Z1'].where(df['y']== -1), df['Z2'].where(df['y']==-1))
# plt.scatter(df['Z1'].where(df['y']== 1), df['Z2'].where(df['y']==1))

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
 

# Creating figure
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
 
# Creating plot
ax.scatter3D(xs=dataset['x'].where(dataset['classlabels']== 0).to_numpy(), ys=dataset['y'].where(dataset['classlabels']== 0).to_numpy(), zs=dataset['probabilities'].where(dataset['classlabels']== 0).to_numpy(), color = "green")
ax.scatter3D(xs=dataset['x'].where(dataset['classlabels']== 1).to_numpy(), ys=dataset['y'].where(dataset['classlabels']== 1).to_numpy(), zs=dataset['probabilities'].where(dataset['classlabels']== 1).to_numpy(), color = "red")
plt.title("simple 3D scatter plot")
 
# show plot
plt.show()

# %% [markdown]
# #The gaussian function

# %%
# import math

# def gaussiankernal(xt,yt):
  
#   xt=xt
#   yt=yt
#   sigma_x = np.std(xt)
#   print(sigma_x)
#   sigma_y = np.std(yt)
#   print(sigma_y)
#   ro= np.corrcoef(xt,yt)[0,1]
#   print(ro)
#   print(xt.shape)
#   z = np.zeros(len(xt))
#   print(z.shape)
#   for i in range(len(xt)):
#     z[i] = math.exp((-1)/(2*(1-ro**2))*((xt[i]**2/sigma_x**2)+(yt[i]**2/sigma_y**2)-((2*ro*xt[i]*yt[i])/(sigma_x*sigma_y))))
#   print(z)
#   return z

# %%
import math

def gaussiankernal(xt,yt):
  
  xt=xt
  yt=yt
  sigma_x = np.std(xt)
  sigma_y = np.std(yt)
  ro= np.corrcoef(xt,yt)[0,1]
  z = np.zeros(len(xt))
  z = math.exp((-1)/(2*(1-ro**2))*((xt**2/sigma_x**2)+(yt**2/sigma_y**2)-((2*ro*xt*yt)/(sigma_x*sigma_y))))
  return z

# %%
dataset['z'] = dataset['x']

# %%
dataset['x'].to_numpy()
# Out:
# array([  2.,   5.,   8.,   4.,   6.,  -2.,  -5.,  -8.,  -4.,  -6.,   2.,
#          5.,   8.,   4.,   6.,  -2.,  -5.,  -8.,  -4.,  -6.,  20., -20.,
#        -20.,  20.,  22.,  22., -22., -22.,  23., -23., -23.,  23.,  25.,
#         25., -25., -25.,  28.,  28., -28., -28.])

# %%
# gaussiankernal(dataset['x'].to_numpy(), dataset['y'].to_numpy())

# %%
# dataset['z'] = gaussiankernal(dataset['x'].to_numpy(), dataset['y'].to_numpy())
# Out:
# 17.22498185775532
# 14.802026888233922
# 0.0
# (40,)
# (40,)
# [0.98425618 0.85731387 0.82695308 0.84112475 0.74910686 0.98425618
#  0.85731387 0.82695308 0.84112475 0.74910686 0.98425618 0.85731387
#  0.82695308 0.84112475 0.74910686 0.98425618 0.85731387 0.82695308
#  0.84112475 0.74910686 0.20455738 0.20455738 0.20455738 0.20455738
#  0.21118366 0.21118366 0.21118366 0.21118366 0.14988864 0.14988864
#  0.14988864 0.14988864 0.11558248 0.11558248 0.11558248 0.11558248
#  0.13797041 0.13797041 0.13797041 0.13797041]

# %%
type(dataset['x'][1])
# Out:
# numpy.float64

# %%
sum(dataset['y'].to_numpy())
# Out:
# 0.0

# %%
dataset
# Out:
#     Unnamed: 0     x     y  classlabels  probabilities         z
# 0            0   2.0   2.0            0       0.956055  0.984256
# 1            1   5.0   7.0            0       0.657183  0.857314
# 2            2   8.0   6.0            0       0.577017  0.826953
# 3            3   4.0   8.0            0       0.636944  0.841125
# 4            4   6.0  10.0            0       0.462753  0.749107
# 5            5  -2.0   2.0            0       0.968619  0.984256
# 6            6  -5.0   7.0            0       0.736712  0.857314
# 7            7  -8.0   6.0            0       0.674881  0.826953
# 8            8  -4.0   8.0            0       0.707066  0.841125
# 9            9  -6.0  10.0            0       0.562856  0.749107
# 10          10   2.0  -2.0            0       0.968619  0.984256
# 11          11   5.0  -7.0            0       0.736712  0.857314
# 12          12   8.0  -6.0            0       0.674881  0.826953
# ...

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
 

# Creating figure
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
 
# Creating plot
ax.scatter3D(xs=dataset['x'].where(dataset['classlabels']== 0).to_numpy(), ys=dataset['y'].where(dataset['classlabels']== 0).to_numpy(), zs=dataset['z'].where(dataset['classlabels']== 0).to_numpy(), color = "green")
ax.scatter3D(xs=dataset['x'].where(dataset['classlabels']== 1).to_numpy(), ys=dataset['y'].where(dataset['classlabels']== 1).to_numpy(), zs=dataset['z'].where(dataset['classlabels']== 1).to_numpy(), color = "red")
plt.title("simple 3D scatter plot")
 
# show plot
plt.show()
