# %% [markdown]
# #make required imports

# %% [markdown]
# #load your data

# %% [markdown]
# #kmeans from scikit learn

# %%
from sklearn.cluster import KMeans
random_state=8
y_pred = KMeans(n_clusters=3, random_state=random_state).fit_predict(data)
plt.scatter(data[:, 0], data[:, 1], c=y_pred)
plt.title("Incorrect Number of Blobs")

# %% [markdown]
# #nonspherical cluster example

# %% [markdown]
# #kmeans with outlier

# %%
data_with_outlier=np.append(data,[[150,150]],axis=0)

# %% [markdown]
# #try DBSCAN

# %%
from sklearn.cluster import DBSCAN

y_pred = DBSCAN (eps=20).fit_predict(data2)
plt.scatter(data2[:, 0], data2[:, 1], c=y_pred)
